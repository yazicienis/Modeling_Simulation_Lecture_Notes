# %% [markdown]
# <a href="https://colab.research.google.com/github/yazicienis/Modeling_Simulation_Lecture_Notes/blob/main/1_Intro_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Python Programming Language**
#
# 1. Data Types
# 2. Mathematical Operations
# 3. Built-In Functions
# 4. Importing Other Modules
# 5. String Methods
# 6. List Methods
# 7. Dictionary Methods
# 8. Keywords
# 8. For and While Loops
# 9. If  - Elif - Else Statements

# %% [markdown]
# # Data Types and Value Assignment
#
# There are several types of data in Python. Some of them are:
#
# 1.   Integers
# 2.   Floats (Fractional Numbers)
# 3.   Lists (Arrays)
# 4.   Strings
# 5. Dictionaries
# 6. Booleans

# %%
x = 5

# %%
type(x)

# %%
y = 5.0

# %%
# Assigning a string to a variable

type(y)

# %%
z = "Hello"
Z = 'Hello'

# %%
type(Z)

# %%
t = [1,2,3.5,"a","y","x", x , y]
t

# %%
type(t)

# %%
t[-1]

# %%
# Dictionary
# Keywords : Values

w = {"brand": "Ford",
     "model": "Mustang",
     "year": 1964}

# %%
w["brand"]

# %%
# Booleans

k1 = 5

type(k1)

# %%
bool(k1)

# %%
print(x,y, k, k1 )
print("This is my first python script!!!", x , "Hello!!", "\n", "I define variables...")

# %%
# Output Function:
# To print out anything, we use print() function:

print(x, y, z)

# %%
print (y)
print (z)
print (t)
print (w)
print (k)

# %%
# Usage of print() function:

print("Hello")
print(x)
print('Hi! Today is rainy.')

# %%
print(" Hello! \n This is my first python script ")

# %%
# Printing out a value of a pre-defined variable in print() function:

print ("The sum of {0} and {1} is {2} ".format(x , y, x+y))

print("The value of x is {}".format(x))

# %%
# How to see the type of a variable:

type(w)

# %%
print(type(y))
print(type(z))
print(type(t))
print(type(w))
print(type(k))

print(type(x),type(y),type(z))

# %% [markdown]
# #Mathematical Operations in Python
#
# * Adddition  +
# * Subtraction  -
# * Multiplication  *
# * Division  /
# * Modulo %
# * Closest integer Division  //
# * Power Operator  **

# %%
x=5
y=4
z= x + y
print (z)

# %%
x+y

# %%
x-y

# %%
x*y

# %%
x/y

# %%
521 % 100

# %%
# Odd Numbers
print(13%2)

#Even numbers

print(12%2)

# %%
print (50 // 12)
print (50 / 12)

# %%
x**y

# %%
x=5
y=4

z = x/y
print(z)
print(type(z))

# %%
s="Hello!"
t="How are you?"
print (s,t)   # 2 parameters
print (s+t)   # 1 parameter

# %%
list1 =[1,2,3]
list2=["a","b","c"]

list3=list2+list1
print(list3)

# %%
f = list1[0] + list1[1]
print(f)

# %% [markdown]
# # Some Built-in Functions
#
# * chr()
# * float()
# * int()
# * input()
# * print()
# * len()
# * max()
# * range()
# * sorted()
# * str()
# * sum()
# * type()

# %%
chr(78)

# %%
chr(105)

# %% [markdown]
# # ASCII Table

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
chr(125)

# %%
# float() , int(), str() functions

a = 9
print(type(a))

# %%
b = float(a)
print(type(b))
print (b)

# %%
c= int(b)
print (type(c))

# %%
d = str(a)

print ("d = ", d)
print ("type of d: ", type(d))
print ("a = ", a)
print ("type of a: ", type(a))

# %%
print(d+d)
print(a+a)

# %%
float(d) + 4

# %%
a + d
# since d is a string and a is a numerical value, we cannot apply math operations:

# %%
a+b

# %%
# input() function

a = input()
print (type(a))

a = float(a)

print (5*a)

# %%
a = input("Please enter any number!")
b = float(a)*float(a)
print("The square of {0} is {1} ".format(a,b))

# %%
# len function

list1 = [1,2,3,[56,21,84]]

len(list1)

# %%
list1[0]

# %%
list1[3]

# %%
# Index of Elements in a List

string1 = "physics"

print("The length of the string is:", len(string1))
print("The zeroth element of the string : " , string1[0])

# %%
# max() and min() functions
list1 =[1,2,3,-96]
max(list1)

# %%
max(3,5,6)

# %%
min(list1)

# %%
list2 = ["name", "surname", "abc", "z"]

min(list2)

# %%
min([3,-5,6])

# %%
# range () function

numbers = range(0,1,0.1)

print (numbers[4])

# %%
list2 = range(5)

print(list2[3])
print(type(list2))

# %%
#sorted () function:

list1 =[1,2,3,-5,-9,9,7]
sorted(list1)

# %%
list1 = sorted(list1)

# %%
list1

# %%
sum(list1)
